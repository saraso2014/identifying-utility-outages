# %%
import pandas as pd

# %%
df = pd.read_csv('tweets_sa_unclean.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Event', 'Stage',
#        'Query Date', 'Query Term', 'Id', 'Username', 'Text', 'Date',
#        'Hashtags', 'Location', '_wkt_geom', 'id', 'xcoord', 'ycoord',
#        'Sentiment'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'],inplace=True)

# %%
df.columns
# Out:
# Index(['Event', 'Stage', 'Query Date', 'Query Term', 'Id', 'Username', 'Text',
#        'Date', 'Hashtags', 'Location', '_wkt_geom', 'id', 'xcoord', 'ycoord',
#        'Sentiment'],
#       dtype='object')

# %%
df.head().T
# Out:
#                                                             0  \
# Event                                         ne_bomb_cyclone
# Stage                                                  before
# Query Date                                         2019-10-15
# Query Term                                       power outage
# Id                                        1183894397492043777
# Username                                           meekers999
# Text        Let's lose Govenor Gruesome in Cali please. He...
# Date                                2019-10-14 23:56:34+00:00
# Hashtags                                                  NaN
# Location                                                  NaN
# _wkt_geom   Point (-77.58788778888725801 38.32415544020682...
# id                                                      17892
# xcoord                                               -77.5879
# ycoord                                                38.3242
# Sentiment                                                   0
#
#                                                             1  \
# Event                                         ne_bomb_cyclone
# Stage                                                  before
# Query Date                                         2019-10-15
# Query Term                                       power outage
# Id                                        1183894362725289984
# Username                                       sharethiscrime
# Text        Last time I checked, he's still a floofy baby ...
# Date                                2019-10-14 23:56:26+00:00
# Hashtags                                                  NaN
# Location                                                  NaN
# _wkt_geom   Point (-76.48550640128354416 38.47508461690389...
# id                                                      17891
# xcoord                                               -76.4855
# ycoord                                                38.4751
# Sentiment                                                   0
#
#                                                             2  \
# Event                                         ne_bomb_cyclone
# Stage                                                  before
# Query Date                                         2019-10-15
# Query Term                                       power outage
# Id                                        1183894014573105152
# Username                                            News_1jl4
# Text        California’s power outage means problems for e...
# Date                                2019-10-14 23:55:03+00:00
# Hashtags                                                  NaN
# Location                                                  NaN
# _wkt_geom   Point (-77.41021456388132549 38.30670835924499...
# id                                                      17894
# xcoord                                               -77.4102
# ycoord                                                38.3067
# Sentiment                                                   0
#
#                                                             3  \
# Event                                         ne_bomb_cyclone
# Stage                                                  before
# Query Date                                         2019-10-15
# Query Term                                       power outage
# Id                                        1183893791415123968
# Username                                           IndeCardio
# Text        Newsome is vanguard Globalism in action! What ...
# Date                                2019-10-14 23:54:10+00:00
# Hashtags                                                  NaN
# Location                                                  NaN
# _wkt_geom   Point (-77.79985279265937947 38.45514536776436...
# id                                                      17893
# xcoord                                               -77.7999
# ycoord                                                38.4551
# Sentiment                                                   0
#
#                                                             4
# Event                                         ne_bomb_cyclone
# Stage                                                  before
# Query Date                                         2019-10-15
# Query Term                                       power outage
# Id                                        1183893732652810240
# Username                                           BaddictsPH
# Text        Super Typhoon Faxai hit Chiba prefecture in Se...
# Date                                2019-10-14 23:53:56+00:00
# Hashtags                                                  NaN
# Location                                                  NaN
# _wkt_geom   Point (-77.83618103291209422 38.62109214538766...
# id                                                      17888
# xcoord                                               -77.8362
# ycoord                                                38.6211
# Sentiment                                                   0

# %%
df.dtypes
# Out:
# Event          object
# Stage          object
# Query Date     object
# Query Term     object
# Id              int64
# Username       object
# Text           object
# Date           object
# Hashtags       object
# Location      float64
# _wkt_geom      object
# id              int64
# xcoord        float64
# ycoord        float64
# Sentiment     float64
# dtype: object
