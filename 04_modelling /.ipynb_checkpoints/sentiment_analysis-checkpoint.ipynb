# %% [markdown]
# ### Sentiment Analysis
#
# Code adapted from lesson 5.03 - Natural Language Processing (Author: Matt Brems)

# %% [markdown]
# **Library Imports**

# %%
import pandas as pd
import numpy as np
import regex as re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %% [markdown]
# **Read in Data**

# %%
df = pd.read_csv('../data/merged/tweets_geom_unclean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            Event   Stage Query Date    Query Term  \
# 0           0             0  ne_bomb_cyclone  before   10/15/19  power outage
# 1           1             1  ne_bomb_cyclone  before   10/15/19  power outage
# 2           2             2  ne_bomb_cyclone  before   10/15/19  power outage
# 3           3             3  ne_bomb_cyclone  before   10/15/19  power outage
# 4           4             4  ne_bomb_cyclone  before   10/15/19  power outage
#
#              Id        Username  \
# 0  1.180000e+18      meekers999
# 1  1.180000e+18  sharethiscrime
# 2  1.180000e+18       News_1jl4
# 3  1.180000e+18      IndeCardio
# 4  1.180000e+18      BaddictsPH
#
#                                                 Text  \
# 0  Let's lose Govenor Gruesome in Cali please. He...
# 1  Last time I checked, he's still a floofy baby ...
# 2  California’s power outage means problems for e...
# 3  Newsome is vanguard Globalism in action! What ...
# 4  Super Typhoon Faxai hit Chiba prefecture in Se...
#
#                         Date Hashtags  Location  \
# 0  2019-10-14 23:56:34+00:00      NaN       NaN
# 1  2019-10-14 23:56:26+00:00      NaN       NaN
# 2  2019-10-14 23:55:03+00:00      NaN       NaN
# 3  2019-10-14 23:54:10+00:00      NaN       NaN
# 4  2019-10-14 23:53:56+00:00      NaN       NaN
#
#                                            _wkt_geom     id     xcoord  \
# 0  Point (-77.58788778888725801 38.32415544020682...  17892 -77.587888
# 1  Point (-76.48550640128354416 38.47508461690389...  17891 -76.485506
# 2  Point (-77.41021456388132549 38.30670835924499...  17894 -77.410215
# 3  Point (-77.79985279265937947 38.45514536776436...  17893 -77.799853
# 4  Point (-77.83618103291209422 38.62109214538766...  17888 -77.836181
#
#       ycoord
# 0  38.324155
# 1  38.475085
# 2  38.306708
# 3  38.455145
# 4  38.621092

# %% [markdown]
# **Define Stopwords, Positive Words, and Negative Words**

# %%
positive_words = ['delight', 'good', 'great', 'awesome', 'tremendous', 'fabulous', 'amazing', 'stellar']
negative_words = ['garbage', 'sad', 'trash', 'ugly', 'bad', 'disgusting', 'terrible', 'gross']

# %%
# Build function to clean each tweet
def sentiment_tweet(tweet):
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(tweet.lower())
    porter_stemmer = PorterStemmer()
    stems_stops = [porter_stemmer.stem(i) for i in tokens]
    stems_only = [w for w in stems_stops if w not in stopwords.words('english')]
    
    
    positive_stems = [porter_stemmer.stem(i) for i in positive_words]
    negative_stems = [porter_stemmer.stem(i) for i in negative_words]
    
    pos_count = sum([1 for i in stems_only if i in positive_stems])
    neg_count = sum([1 for i in stems_only if i in negative_stems])
    
    return round((pos_count - neg_count) / len(tokens), 2)

# %% [markdown]
# **Test Sample Subset of Tweets**

# %%
test2 = df[500:505]

# %%
test2['SA'] = test2['Text'].apply(sentiment_tweet)
# Out:
# /Users/sarasoueidan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test2.T
# Out:
#                                                             500  \
# Unnamed: 0                                                  500
# Unnamed: 0.1                                                500
# Event                                           ne_bomb_cyclone
# Stage                                                    before
# Query Date                                             10/15/19
# Query Term                                         power outage
# Id                                                     1.18e+18
# Username                                             KatyVaux36
# Text          California’s massive power outages remind us a...
# Date                                  2019-10-14 17:10:43+00:00
# Hashtags                                                    NaN
# Location                                                    NaN
# _wkt_geom     Point (-78.0175450188474997 38.59067895901865342)
# id                                                        17424
# xcoord                                                 -78.0175
# ycoord                                                  38.5907
# SA                                                            0
#
#                                                             501  \
# Unnamed: 0                                                  501
# Unnamed: 0.1                                                501
# Event                                           ne_bomb_cyclone
# Stage                                                    before
# Query Date                                             10/15/19
# Query Term                                         power outage
# Id                                                     1.18e+18
# Username                                              colleenve
# Text          @CityPowerJhb Power outage Halfway Gardens Mid...
# Date                                  2019-10-14 17:09:21+00:00
# Hashtags                                                    NaN
# Location                                                    NaN
# _wkt_geom     Point (-78.02639358017009386 39.27817515025316...
# id                                                        17423
# xcoord                                                 -78.0264
# ycoord                                                  39.2782
# SA                                                            0
#
#                                                             502  \
# Unnamed: 0                                                  502
# Unnamed: 0.1                                                502
# Event                                           ne_bomb_cyclone
# Stage                                                    before
# Query Date                                             10/15/19
# Query Term                                         power outage
# Id                                                     1.18e+18
# Username                                              hubblyguy
# Text          @CityPowerJhb power outage in Midrand Halfway ...
# Date                                  2019-10-14 17:09:10+00:00
# Hashtags                                                    NaN
# Location                                                    NaN
# _wkt_geom     Point (-76.76066993423279428 38.58503849750882...
# id                                                        17426
# xcoord                                                 -76.7607
# ycoord                                                   38.585
# SA                                                            0
#
#                                                             503  \
# Unnamed: 0                                                  503
# Unnamed: 0.1                                                503
# Event                                           ne_bomb_cyclone
# Stage                                                    before
# Query Date                                             10/15/19
# Query Term                                         power outage
# Id                                                     1.18e+18
# Username                                              MariYUH00
# Text          Work is about to be hella backed up because of...
# Date                                  2019-10-14 17:09:09+00:00
# Hashtags                                                    NaN
# Location                                                    NaN
# _wkt_geom     Point (-76.68207350966476099 38.92840805117187...
# id                                                        17425
# xcoord                                                 -76.6821
# ycoord                                                  38.9284
# SA                                                            0
#
#                                                             504
# Unnamed: 0                                                  504
# Unnamed: 0.1                                                504
# Event                                           ne_bomb_cyclone
# Stage                                                    before
# Query Date                                             10/15/19
# Query Term                                         power outage
# Id                                                     1.18e+18
# Username                                         juango_snijack
# Text          2/5 we don't have food,we don't have medicine ...
# Date                                  2019-10-14 17:08:35+00:00
# Hashtags                                                    NaN
# Location                                                    NaN
# _wkt_geom     Point (-76.39998139390685594 38.35518154465766...
# id                                                        17436
# xcoord                                                    -76.4
# ycoord                                                  38.3552
# SA                                                        -0.02

# %% [markdown]
# **Run Tweets Through Functions**

# %%
df['Sentiment'] = df['Text'].apply(sentiment_tweet)

# %%
df['Sentiment'].sort_values()
# Out:
# 4204    -0.14
# 11589   -0.14
# 2237    -0.12
# 931     -0.10
# 10316   -0.09
#          ...
# 9256     0.25
# 13316    0.25
# 4318     0.25
# 10818    0.33
# 14909    0.33
# Name: Sentiment, Length: 18000, dtype: float64

# %%
df.loc[10]['Text']
# Out:
# 'Manitoba is getting reinforcements to deal w/ widespread power outages. Details at 6 SK time w/ GX94 News.'

# %%
break

# %%
# Export to data folder:

df.to_csv('../data/merged/tweets_sa_unclean.csv')
